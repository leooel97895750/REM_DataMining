# %%
import pandas as pd
import numpy as np

summary6 = open("summary6.csv", "r")

rem_text = summary6.read()
text_split = rem_text.split('\n')
rem_data = np.array(text_split[0].split(','))

bad_list = ['P008']
for i in range(1, len(text_split)-1):
    line = text_split[i].split(',')
    if line[1] not in bad_list:
        rem_data = np.vstack((rem_data, line))
        
pd.set_option('display.max_columns', None)
df = pd.DataFrame(rem_data[1:], columns=rem_data[0])
df
# Out:
#    name    id o_rem_num x_rem_num o_rem_duration x_rem_duration o_rem_avg  \
# 0   陳碧蓮  P001         9         6           4620           2460       513
# 1   陳佳星  P002         7         8           4740           3990       677
# 2   袁賽芳  P003         6         5           3990           5700       655
# 3   鄭雅菁  P004         9         8           4230           5190       470
# 4   謝秀珍  P005         8         7           6780           6510       848
# 5   黃淑惠  P006         7         8           4770           4860       681
# 6   陳淑美  P007         3         5           1920           1950       640
# 7   郭秉羱  P009         6         7           3360           3900       560
# 8   張柏瑞  P010         7         7           2700           3930       386
# 9   莊惠雅  P011        13         6           3210           1050       247
# 10  黃惠玲  P012         5         9           4860           6150       972
# 11  陳秋盈  P013        16        11           3390           3030       212
# ...

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

# 自身cortisol變化量來比較睡眠指標

under_zero = ['P013', 'P024', 'P007', 'P009', 'P026', 'P036', 'P003', 'P037', 'P023', 'P018', 'P019', 'P032']
above_zero = ['P033', 'P016', 'P002', 'P039', 'P004', 'P020', 'P022', 'P012', 'P011', 'P035', 'P034', 'P017', 'P040', 'P028', 'P006', 'P031', 'P027', 'P001', 'P029', 'P015', 'P005', 'P038', 'P030', 'P021', 'P014', 'P010', 'P025']
under_half = ['P013', 'P024', 'P007', 'P009', 'P026', 'P036', 'P003', 'P037', 'P023', 'P018', 'P019', 'P032', 'P033', 'P016', 'P002', 'P039', 'P004', 'P020', 'P022', 'P012']
above_half = ['P011', 'P035', 'P034', 'P017', 'P040', 'P028', 'P006', 'P031', 'P027', 'P001', 'P029', 'P015', 'P005', 'P038', 'P030', 'P021', 'P014', 'P010', 'P025']

now_ids = under_zero

#REM總次數 o
o_rem_num = []
for i in range(len(now_ids)):
    data = df.loc[df['id'] == now_ids[i]]
    o_rem_num.append(np.array(data['o_rem_num'], dtype=np.int64)[0])
print(o_rem_num)

#REM總次數 x
x_rem_num = []
for i in range(len(now_ids)):
    data = df.loc[df['id'] == now_ids[i]]
    x_rem_num.append(np.array(data['x_rem_num'], dtype=np.int64)[0])
print(x_rem_num)

#REM總時間 o
o_rem_duration = []
for i in range(len(now_ids)):
    data = df.loc[df['id'] == now_ids[i]]
    o_rem_duration.append(np.array(data['o_rem_duration'], dtype=np.int64)[0])
print(o_rem_duration)

#REM總時間 x
x_rem_duration = []
for i in range(len(now_ids)):
    data = df.loc[df['id'] == now_ids[i]]
    x_rem_duration.append(np.array(data['x_rem_duration'], dtype=np.int64)[0])
print(x_rem_duration)

#REM平均長度 o
o_rem_avg = []
for i in range(len(now_ids)):
    data = df.loc[df['id'] == now_ids[i]]
    o_rem_avg.append(np.array(data['o_rem_avg'], dtype=np.int64)[0])
print(o_rem_avg)

#REM平均長度 x
x_rem_avg = []
for i in range(len(now_ids)):
    data = df.loc[df['id'] == now_ids[i]]
    x_rem_avg.append(np.array(data['x_rem_avg'], dtype=np.int64)[0])
print(x_rem_avg)

#REM fragmentation o
o_rem_frag = []
for i in range(len(now_ids)):
    data = df.loc[df['id'] == now_ids[i]]
    o_rem_frag.append(np.array(data['o_rem_frag'], dtype=np.single)[0])
print(o_rem_frag)

#REM fragmentation x
x_rem_frag = []
for i in range(len(now_ids)):
    data = df.loc[df['id'] == now_ids[i]]
    x_rem_frag.append(np.array(data['x_rem_frag'], dtype=np.single)[0])
print(x_rem_frag)

#REM latency o
o_rem_latency = []
for i in range(len(now_ids)):
    data = df.loc[df['id'] == now_ids[i]]
    o_rem_latency.append(np.array(data['o_rem_latency'], dtype=np.int64)[0])
print(o_rem_latency)

#REM latency x
x_rem_latency = []
for i in range(len(now_ids)):
    data = df.loc[df['id'] == now_ids[i]]
    x_rem_latency.append(np.array(data['x_rem_latency'], dtype=np.int64)[0])
print(x_rem_latency)

#REM density o
o_rem_density = []
for i in range(len(now_ids)):
    data = df.loc[df['id'] == now_ids[i]]
    o_rem_density.append(np.array(data['o_rem_density'], dtype=np.single)[0])
print(o_rem_density)

#REM density x
x_rem_density = []
for i in range(len(now_ids)):
    data = df.loc[df['id'] == now_ids[i]]
    x_rem_density.append(np.array(data['x_rem_density'], dtype=np.single)[0])
print(x_rem_density)

# 柱狀圖分析
labels = now_ids
x = np.arange(len(labels))
width = 0.20

plt.figure(figsize=(24,6))
plt.bar(x - width/2, o_rem_num, width)
plt.bar(x + width/2, x_rem_num, width)
plt.xticks(x, labels)

# 變化量分析
diff_rem_num = np.array(o_rem_num) - np.array(x_rem_num)
plt.figure(figsize=(24,3))
plt.scatter(x=now_ids, y=diff_rem_num, c='blue')
plt.axhline(y=0, c='red')
# Out:
# [16, 13, 3, 6, 6, 6, 6, 13, 7, 8, 10, 6]
# [11, 12, 5, 7, 9, 3, 5, 10, 6, 4, 7, 7]
# [3390, 7320, 1920, 3360, 3570, 2370, 3990, 2880, 4740, 4410, 6690, 5160]
# [3030, 5370, 1950, 3900, 3960, 1710, 5700, 5760, 2520, 2400, 7710, 3930]
# [212, 563, 640, 560, 595, 395, 655, 222, 677, 551, 669, 860]
# [275, 448, 390, 557, 440, 570, 1140, 576, 420, 600, 1024, 561]
# [4.2242, 6.6352, 1.4323, 0.9077, 1.4314, 4.3671, 7.0125, 3.941, 0.8544, 11.46, 6.8984, 1.4128]
# [4.2541, 3.5661, 3.5026, 0.741, 1.8586, 2.6959, 6.8386, 6.0486, 4.3571, 9.6083, 4.6527, 1.5293]
# [4860, 5880, 15540, 8880, 3900, 11610, 6420, 4020, 4080, 7140, 3780, 4410]
# [4170, 5010, 19440, 5820, 3210, 14910, 6600, 4200, 7560, 14010, 4020, 13230]
# [22.389, 27.281, 15.573, 9.6131, 15.966, 7.4262, 20.401, 22.986, 9.4093, 34.014, 10.284, 23.004]
# [31.98, 33.091, 46.718, 11.692, 19.369, 9.1228, 11.509, 23.264, 10.794, 27.333, 16.597, 22.774]

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

# 自身cortisol變化量來比較睡眠指標

under_zero = ['P013', 'P024', 'P007', 'P009', 'P026', 'P036', 'P003', 'P037', 'P023', 'P018', 'P019', 'P032']
above_zero = ['P033', 'P016', 'P002', 'P039', 'P004', 'P020', 'P022', 'P012', 'P011', 'P035', 'P034', 'P017', 'P040', 'P028', 'P006', 'P031', 'P027', 'P001', 'P029', 'P015', 'P005', 'P038', 'P030', 'P021', 'P014', 'P010', 'P025']
under_half = ['P013', 'P024', 'P007', 'P009', 'P026', 'P036', 'P003', 'P037', 'P023', 'P018', 'P019', 'P032', 'P033', 'P016', 'P002', 'P039', 'P004', 'P020', 'P022', 'P012']
above_half = ['P011', 'P035', 'P034', 'P017', 'P040', 'P028', 'P006', 'P031', 'P027', 'P001', 'P029', 'P015', 'P005', 'P038', 'P030', 'P021', 'P014', 'P010', 'P025']

abs_cortisol = ['P019_x' 'P012_x' 'P017_x' 'P025_o' 'P031_x' 'P024_o' 'P017_o' 'P012_o'
 'P039_x' 'P030_x' 'P033_x' 'P001_x' 'P025_x' 'P038_x' 'P023_x' 'P024_x'
 'P031_o' 'P023_o' 'P011_x' 'P029_x' 'P028_o' 'P035_x' 'P005_o' 'P037_o'
 'P002_o' 'P005_x' 'P020_o' 'P029_o' 'P022_o' 'P016_x' 'P010_x' 'P011_o'
 'P013_o' 'P003_o' 'P015_x' 'P015_o' 'P032_x' 'P004_x' 'P040_x' 'P021_x'
 'P038_o' 'P018_x' 'P010_o' 'P021_o' 'P036_o' 'P020_x' 'P001_o' 'P019_o'
 'P003_x' 'P014_o' 'P032_o' 'P006_o' 'P037_x' 'P004_o' 'P022_x' 'P013_x'
 'P018_o' 'P035_o' 'P033_o' 'P039_o' 'P027_x' 'P028_x' 'P006_x' 'P009_x'
 'P036_x' 'P009_o' 'P007_x' 'P040_o' 'P030_o' 'P002_x' 'P007_o' 'P014_x'
 'P016_o' 'P034_x' 'P034_o' 'P026_o' 'P026_x' 'P027_o']

diff_pm = ['P002', 'P028', 'P014', 'P037', 'P036', 'P022', 'P013', 'P020', 'P003', 'P006',
 'P025', 'P024', 'P005', 'P026', 'P015', 'P023', 'P034', 'P009', 'P021', 'P007',
 'P017', 'P010', 'P032', 'P029', 'P031', 'P011', 'P018', 'P004', 'P012', 'P038',
 'P001', 'P040', 'P035', 'P033', 'P016', 'P039', 'P027', 'P019', 'P030',]

ahi8 = ['P004', 'P040', 'P023', 'P024', 'P025', 'P012', 'P039', 'P010',
       'P017', 'P013']

now_ids = ahi8

# o AHI
o_ahi = []
for i in range(len(now_ids)):
    data = df.loc[df['id'] == now_ids[i]]
    o_ahi.append(np.array(data['o_ahi'], dtype=np.single)[0])
print(o_ahi)

# x AHI
x_ahi = []
for i in range(len(now_ids)):
    data = df.loc[df['id'] == now_ids[i]]
    x_ahi.append(np.array(data['x_ahi'], dtype=np.single)[0])
print(x_ahi)

#REM總次數 o
o_rem_num = []
for i in range(len(now_ids)):
    data = df.loc[df['id'] == now_ids[i]]
    o_rem_num.append(np.array(data['o_rem_num'], dtype=np.int64)[0])
print(o_rem_num)

#REM總次數 x
x_rem_num = []
for i in range(len(now_ids)):
    data = df.loc[df['id'] == now_ids[i]]
    x_rem_num.append(np.array(data['x_rem_num'], dtype=np.int64)[0])
print(x_rem_num)

#REM總時間 o
o_rem_duration = []
for i in range(len(now_ids)):
    data = df.loc[df['id'] == now_ids[i]]
    o_rem_duration.append(np.array(data['o_rem_duration'], dtype=np.int64)[0])
print(o_rem_duration)

#REM總時間 x
x_rem_duration = []
for i in range(len(now_ids)):
    data = df.loc[df['id'] == now_ids[i]]
    x_rem_duration.append(np.array(data['x_rem_duration'], dtype=np.int64)[0])
print(x_rem_duration)

#REM平均長度 o
o_rem_avg = []
for i in range(len(now_ids)):
    data = df.loc[df['id'] == now_ids[i]]
    o_rem_avg.append(np.array(data['o_rem_avg'], dtype=np.int64)[0])
print(o_rem_avg)

#REM平均長度 x
x_rem_avg = []
for i in range(len(now_ids)):
    data = df.loc[df['id'] == now_ids[i]]
    x_rem_avg.append(np.array(data['x_rem_avg'], dtype=np.int64)[0])
print(x_rem_avg)

#REM fragmentation o
o_rem_frag = []
for i in range(len(now_ids)):
    data = df.loc[df['id'] == now_ids[i]]
    o_rem_frag.append(np.array(data['o_rem_frag'], dtype=np.single)[0])
print(o_rem_frag)

#REM fragmentation x
x_rem_frag = []
for i in range(len(now_ids)):
    data = df.loc[df['id'] == now_ids[i]]
    x_rem_frag.append(np.array(data['x_rem_frag'], dtype=np.single)[0])
print(x_rem_frag)

#REM latency o
o_rem_latency = []
for i in range(len(now_ids)):
    data = df.loc[df['id'] == now_ids[i]]
    o_rem_latency.append(np.array(data['o_rem_latency'], dtype=np.int64)[0])
print(o_rem_latency)

#REM latency x
x_rem_latency = []
for i in range(len(now_ids)):
    data = df.loc[df['id'] == now_ids[i]]
    x_rem_latency.append(np.array(data['x_rem_latency'], dtype=np.int64)[0])
print(x_rem_latency)

#REM density o
o_rem_density = []
for i in range(len(now_ids)):
    data = df.loc[df['id'] == now_ids[i]]
    o_rem_density.append(np.array(data['o_rem_density'], dtype=np.single)[0])
print(o_rem_density)

#REM density x
x_rem_density = []
for i in range(len(now_ids)):
    data = df.loc[df['id'] == now_ids[i]]
    x_rem_density.append(np.array(data['x_rem_density'], dtype=np.single)[0])
print(x_rem_density)

#REM per o
o_rem_per = []
for i in range(len(now_ids)):
    data = df.loc[df['id'] == now_ids[i]]
    o_rem_per.append(np.array(data['o_rem_per'], dtype=np.single)[0])
print(o_rem_per)

#REM per x
x_rem_per = []
for i in range(len(now_ids)):
    data = df.loc[df['id'] == now_ids[i]]
    x_rem_per.append(np.array(data['x_rem_per'], dtype=np.single)[0])
print(x_rem_per)

#cortisol pm o
o_pm_cortisol = []
for i in range(len(now_ids)):
    data = df.loc[df['id'] == now_ids[i]]
    o_pm_cortisol.append(np.array(data['o_pm_cortisol'], dtype=np.single)[0])
print(o_pm_cortisol)

#cortisol pm x
x_pm_cortisol = []
for i in range(len(now_ids)):
    data = df.loc[df['id'] == now_ids[i]]
    x_pm_cortisol.append(np.array(data['x_pm_cortisol'], dtype=np.single)[0])
print(x_pm_cortisol)

#cortisol am o
o_am_cortisol = []
for i in range(len(now_ids)):
    data = df.loc[df['id'] == now_ids[i]]
    o_am_cortisol.append(np.array(data['o_am_cortisol'], dtype=np.single)[0])
print(o_am_cortisol)

#cortisol am x
x_am_cortisol = []
for i in range(len(now_ids)):
    data = df.loc[df['id'] == now_ids[i]]
    x_am_cortisol.append(np.array(data['x_am_cortisol'], dtype=np.single)[0])
print(x_am_cortisol)

# 柱狀圖分析
labels = now_ids
x = np.arange(len(labels))
width = 0.20

plt.figure(figsize=(24,6))
plt.bar(x - width/2, o_rem_frag, width)
plt.bar(x + width/2, x_rem_frag, width)
# plt.axhline(y=4200, c='red')
plt.xticks(x, labels)

plt.figure(figsize=(24,6))
plt.bar(x - width/2, o_am_cortisol, width)
plt.bar(x + width/2, x_am_cortisol, width)
plt.xticks(x, labels)

# 變化量分析
# diff_rem = np.array(o_rem_latency) - np.array(x_rem_latency)
# plt.figure(figsize=(24,3))
# plt.scatter(x=now_ids, y=diff_rem, c='blue')
# plt.axhline(y=0, c='red')
# Out:
# [4.1, 6.8, 7.2, 9.4, 10.3, 12.5, 13.4, 14.0, 14.8, 14.9]
# [7.6, 5.8, 10.1, 9.4, 15.9, 10.0, 13.7, 11.6, 12.5, 12.8]
# [9, 10, 7, 13, 6, 5, 9, 7, 7, 16]
# [8, 6, 6, 12, 6, 9, 10, 7, 8, 11]
# [4230, 5430, 4740, 7320, 5430, 4860, 4590, 2700, 3270, 3390]
# [5190, 3360, 2520, 5370, 5430, 6150, 4740, 3930, 4470, 3030]
# [470, 543, 677, 563, 905, 972, 510, 386, 467, 212]
# [649, 560, 420, 448, 905, 683, 474, 561, 559, 275]
# [5.2128, 9.3904, 0.8544, 6.6352, 5.7569, 4.751, 2.7233, 9.5444, 7.0031, 4.2242]
# [7.3565, 6.1458, 4.3571, 3.5661, 7.5396, 4.2, 4.192, 6.1959, 6.783, 4.2541]
# [6330, 6090, 4080, 5880, 5040, 11190, 6330, 4500, 5280, 4860]
# [8670, 5850, 7560, 5010, 3810, 6090, 5520, 4200, 5460, 4170]
# [32.648, 15.414, 9.4093, 27.281, 15.212, 18.827, 11.46, 32.148, 5.9633, 22.389]
# [32.486, 12.917, 10.794, 33.091, 19.153, 25.675, 10.063, 19.211, 8.5011, 31.98]
# [19.9, 23.4, 21.1, 29.4, 21.1, 25.6, 18.5, 13.0, 13.7, 14.6]
# [22.8, 20.1, 12.6, 22.2, 21.2, 25.4, 18.9, 18.9, 20.7, 12.2]
# ...

# %%
print(np.mean(o_ahi[0:20]))
print(np.mean(o_ahi[21:]))
print((np.mean(np.array(o_ahi) - np.array(x_ahi))))
# Out:
# 13.445
# 23.427776
# 0.37179476

# %%
left = diff_rem[:20]
right = diff_rem[21:]

print('左mean、std')
print(np.mean(left))
print(np.std(left))

print('右mean、std')
print(np.mean(right))
print(np.std(right))
# Out:
# 左mean、std
# -1.5
# 1301.857423069055
# 右mean、std
# 315.0
# 1170.4806704939642

# %%
df
# Out:
#    name    id o_rem_num x_rem_num o_rem_duration x_rem_duration o_rem_avg  \
# 0   陳碧蓮  P001         9         6           4620           2460       513
# 1   陳佳星  P002         7         8           4740           3990       677
# 2   袁賽芳  P003         6         5           3990           5700       655
# 3   鄭雅菁  P004         9         8           4230           5190       470
# 4   謝秀珍  P005         8         7           6780           6510       848
# 5   黃淑惠  P006         7         8           4770           4860       681
# 6   陳淑美  P007         3         5           1920           1950       640
# 7   郭秉羱  P009         6         7           3360           3900       560
# 8   張柏瑞  P010         7         7           2700           3930       386
# 9   莊惠雅  P011        13         6           3210           1050       247
# 10  黃惠玲  P012         5         9           4860           6150       972
# 11  陳秋盈  P013        16        11           3390           3030       212
# ...

# %%
# 整體 mean sd

l = 20
r = -1

index = 'o_rem_num'
# rem = np.array(df[index], dtype=np.int64)
rem = o_rem_num[l:r]
print()
print(index)
print(round(np.mean(rem), 2))
print(round(np.std(rem), 2))

index = 'x_rem_num'
# rem = np.array(df[index], dtype=np.int64)
rem = x_rem_num[l:r]
print()
print(index)
print(round(np.mean(rem), 2))
print(round(np.std(rem), 2))

index = 'o_rem_duration'
# rem = np.array(df[index], dtype=np.int64)
rem = o_rem_duration[l:r]
print()
print(index)
print(round(np.mean(rem), 2))
print(round(np.std(rem), 2))

index = 'x_rem_duration'
# rem = np.array(df[index], dtype=np.int64)
rem = x_rem_duration[l:r]
print()
print(index)
print(round(np.mean(rem), 2))
print(round(np.std(rem), 2))

index = 'o_rem_avg'
# rem = np.array(df[index], dtype=np.int64)
rem = o_rem_avg[l:r]
print()
print(index)
print(round(np.mean(rem), 2))
print(round(np.std(rem), 2))

index = 'x_rem_avg'
# rem = np.array(df[index], dtype=np.int64)
rem = x_rem_avg[l:r]
print()
print(index)
print(round(np.mean(rem), 2))
print(round(np.std(rem), 2))

index = 'o_rem_frag'
# rem = np.array(df[index], dtype=np.single)
rem = o_rem_frag[l:r]
print()
print(index)
print(round(np.mean(rem), 2))
print(round(np.std(rem), 2))

index = 'x_rem_frag'
# rem = np.array(df[index], dtype=np.single)
rem = x_rem_frag[l:r]
print()
print(index)
print(round(np.mean(rem), 2))
print(round(np.std(rem), 2))

index = 'o_rem_latency'
# rem = np.array(df[index], dtype=np.int64)
rem = o_rem_latency[l:r]
print()
print(index)
print(round(np.mean(rem), 2))
print(round(np.std(rem), 2))

index = 'x_rem_latency'
# rem = np.array(df[index], dtype=np.int64)
rem = x_rem_latency[l:r]
print()
print(index)
print(round(np.mean(rem), 2))
print(round(np.std(rem), 2))

index = 'o_rem_density'
# rem = np.array(df[index], dtype=np.single)
rem = o_rem_density[l:r]
print()
print(index)
print(round(np.mean(rem), 2))
print(round(np.std(rem), 2))

index = 'x_rem_density'
# rem = np.array(df[index], dtype=np.single)
rem = x_rem_density[l:r]
print()
print(index)
print(round(np.mean(rem), 2))
print(round(np.std(rem), 2))

index = 'o_rem_per'
# rem = np.array(df[index], dtype=np.single)
rem = o_rem_per[l:r]
print()
print(index)
print(round(np.mean(rem), 2))
print(round(np.std(rem), 2))

index = 'x_rem_per'
# rem = np.array(df[index], dtype=np.single)
rem = x_rem_per[l:r]
print()
print(index)
print(round(np.mean(rem), 2))
print(round(np.std(rem), 2))
# Out:
# o_rem_num
# 7.61
# 2.34
#
# x_rem_num
# 7.33
# 4.03
#
# o_rem_duration
# 4066.67
# 1270.87
#
# x_rem_duration
# 3848.33
# 1629.44
#
# o_rem_avg
# 583.83
# 230.9
#
# x_rem_avg
# 627.67
# 341.6
#
# o_rem_frag
# 7.6
# 4.7
#
# x_rem_frag
# 7.09
# 5.36
#
# o_rem_latency
# 6813.33
# 2769.64
#
# x_rem_latency
# 8168.33
# 3991.98
#
# o_rem_density
# 23.79
# 11.98
#
# x_rem_density
# 23.58
# 11.16
#
# o_rem_per
# 15.89
# 4.71
#
# x_rem_per
# 15.37
# 6.06

# %%
a = np.array([3,4,5])
b = np.array([1,1,1])

c = a - b
print(c)
# Out:
# [2 3 4]

# %%
# 整體 差值 mean sd

l = 20
r = -1


o_rem = np.array(o_rem_num[l:r], dtype=np.int64)
x_rem = np.array(x_rem_num[l:r], dtype=np.int64)
rem = o_rem - x_rem
print()
print('diff_rem_num')
print(round(np.mean(rem), 2))
print(round(np.std(rem), 2))

o_rem = np.array(o_rem_duration[l:r], dtype=np.int64)
x_rem = np.array(x_rem_duration[l:r], dtype=np.int64)
rem = o_rem - x_rem
print()
print('diff_rem_duration')
print(round(np.mean(rem), 2))
print(round(np.std(rem), 2))

o_rem = np.array(o_rem_avg[l:r], dtype=np.int64)
x_rem = np.array(x_rem_avg[l:r], dtype=np.int64)
rem = o_rem - x_rem
print()
print('diff_rem_avg')
print(round(np.mean(rem), 2))
print(round(np.std(rem), 2))

o_rem = np.array(o_rem_frag[l:r], dtype=np.single)
x_rem = np.array(x_rem_frag[l:r], dtype=np.single)
rem = o_rem - x_rem
print()
print('diff_rem_frag')
print(round(np.mean(rem), 2))
print(round(np.std(rem), 2))

o_rem = np.array(o_rem_latency[l:r], dtype=np.int64)
x_rem = np.array(x_rem_latency[l:r], dtype=np.int64)
rem = o_rem - x_rem
print()
print('diff_rem_latency')
print(round(np.mean(rem), 2))
print(round(np.std(rem), 2))

o_rem = np.array(o_rem_density[l:r], dtype=np.int64)
x_rem = np.array(x_rem_density[l:r], dtype=np.int64)
rem = o_rem - x_rem
print()
print('diff_rem_density')
print(round(np.mean(rem), 2))
print(round(np.std(rem), 2))

o_rem = np.array(o_rem_per[l:r], dtype=np.int64)
x_rem = np.array(x_rem_per[l:r], dtype=np.int64)
rem = o_rem - x_rem
print()
print('diff_rem_per')
print(round(np.mean(rem), 2))
print(round(np.std(rem), 2))
# Out:
# diff_rem_num
# 0.28
# 4.69
#
# diff_rem_duration
# 218.33
# 1359.7
#
# diff_rem_avg
# -43.83
# 360.88
#
# diff_rem_frag
# 0.5
# 1.81
#
# diff_rem_latency
# -1355.0
# 4868.1
#
# diff_rem_density
# 0.28
# 9.4
#
# diff_rem_per
# 0.56
# 5.1

# %%
ids = np.array(df['id'])
ids1 = ids + "_o"
ids2 = ids + "_x"
ids = np.hstack((ids1, ids2))

o_pm_cortisol = np.array(df['o_pm_cortisol'], dtype=np.single)
x_pm_cortisol = np.array(df['x_pm_cortisol'], dtype=np.single)
pm_cortisol = np.hstack((o_pm_cortisol, x_pm_cortisol))

d = {"ids": ids, "pm_cortisol": pm_cortisol}
df2 = pd.DataFrame(data=d)
df2 = df2.sort_values('pm_cortisol')

x = np.array(df2['ids'])
y = np.array(df2['pm_cortisol'])

plt.figure(figsize=(24,4))
plt.yticks(np.arange(1, 12, 0.5))  
plt.rcParams['font.sans-serif'] = ['Taipei Sans TC Beta']
plt.scatter(x=x, y=y)

print(np.array(df2['ids']))
# Out:
# ['P019_x' 'P012_x' 'P017_x' 'P025_o' 'P031_x' 'P024_o' 'P017_o' 'P012_o'
#  'P039_x' 'P030_x' 'P033_x' 'P001_x' 'P025_x' 'P038_x' 'P023_x' 'P024_x'
#  'P031_o' 'P023_o' 'P011_x' 'P029_x' 'P028_o' 'P035_x' 'P005_o' 'P037_o'
#  'P002_o' 'P005_x' 'P020_o' 'P029_o' 'P022_o' 'P016_x' 'P010_x' 'P011_o'
#  'P013_o' 'P003_o' 'P015_x' 'P015_o' 'P032_x' 'P004_x' 'P040_x' 'P021_x'
#  'P038_o' 'P018_x' 'P010_o' 'P021_o' 'P036_o' 'P020_x' 'P001_o' 'P019_o'
#  'P003_x' 'P014_o' 'P032_o' 'P006_o' 'P037_x' 'P004_o' 'P022_x' 'P013_x'
#  'P018_o' 'P035_o' 'P033_o' 'P039_o' 'P027_x' 'P028_x' 'P006_x' 'P009_x'
#  'P036_x' 'P009_o' 'P007_x' 'P040_o' 'P030_o' 'P002_x' 'P007_o' 'P014_x'
#  'P016_o' 'P034_x' 'P034_o' 'P026_o' 'P026_x' 'P027_o']

# %%
abs_cortisol = ['P019_x', 'P012_x', 'P017_x', 'P025_o', 'P031_x', 'P024_o', 'P017_o', 'P012_o',
 'P039_x', 'P030_x', 'P033_x', 'P001_x', 'P025_x', 'P038_x', 'P023_x', 'P024_x',
 'P031_o', 'P023_o', 'P011_x', 'P029_x', 'P028_o', 'P035_x', 'P005_o', 'P037_o',
 'P002_o', 'P005_x', 'P020_o', 'P029_o', 'P022_o', 'P016_x', 'P010_x', 'P011_o',
 'P013_o', 'P003_o', 'P015_x', 'P015_o', 'P032_x', 'P004_x', 'P040_x', 'P021_x',
 'P038_o', 'P018_x', 'P010_o', 'P021_o', 'P036_o', 'P020_x', 'P001_o', 'P019_o',
 'P003_x', 'P014_o', 'P032_o', 'P006_o', 'P037_x', 'P004_o', 'P022_x', 'P013_x',
 'P018_o', 'P035_o', 'P033_o', 'P039_o', 'P027_x', 'P028_x', 'P006_x', 'P009_x',
 'P036_x', 'P009_o', 'P007_x', 'P040_o', 'P030_o', 'P002_x', 'P007_o', 'P014_x',
 'P016_o', 'P034_x', 'P034_o', 'P026_o', 'P026_x', 'P027_o']

#REM總次數
rem_num = []
for i in range(len(abs_cortisol)):
    ids = abs_cortisol[i].split('_')
    data = df.loc[df['id'] == ids[0]]
    if ids[1] == 'o':
        rem_num.append(np.array(data['o_rem_num'], dtype=np.int64)[0])
    else:
        rem_num.append(np.array(data['x_rem_num'], dtype=np.int64)[0])
print(rem_num)

#REM總時間
rem_duration = []
for i in range(len(abs_cortisol)):
    ids = abs_cortisol[i].split('_')
    data = df.loc[df['id'] == ids[0]]
    if ids[1] == 'o':
        rem_duration.append(np.array(data['o_rem_duration'], dtype=np.int64)[0])
    else:
        rem_duration.append(np.array(data['x_rem_duration'], dtype=np.int64)[0])
print(rem_duration)

#REM平均時間
rem_avg = []
for i in range(len(abs_cortisol)):
    ids = abs_cortisol[i].split('_')
    data = df.loc[df['id'] == ids[0]]
    if ids[1] == 'o':
        rem_avg.append(np.array(data['o_rem_avg'], dtype=np.int64)[0])
    else:
        rem_avg.append(np.array(data['x_rem_avg'], dtype=np.int64)[0])
print(rem_avg)

#REM fragmentation
rem_frag = []
for i in range(len(abs_cortisol)):
    ids = abs_cortisol[i].split('_')
    data = df.loc[df['id'] == ids[0]]
    if ids[1] == 'o':
        rem_frag.append(np.array(data['o_rem_frag'], dtype=np.single)[0])
    else:
        rem_frag.append(np.array(data['x_rem_frag'], dtype=np.single)[0])
print(rem_frag)

#REM latency
rem_latency = []
for i in range(len(abs_cortisol)):
    ids = abs_cortisol[i].split('_')
    data = df.loc[df['id'] == ids[0]]
    if ids[1] == 'o':
        rem_latency.append(np.array(data['o_rem_latency'], dtype=np.int64)[0])
    else:
        rem_latency.append(np.array(data['x_rem_latency'], dtype=np.int64)[0])
print(rem_latency)

#REM density
rem_density = []
for i in range(len(abs_cortisol)):
    ids = abs_cortisol[i].split('_')
    data = df.loc[df['id'] == ids[0]]
    if ids[1] == 'o':
        rem_density.append(np.array(data['o_rem_density'], dtype=np.single)[0])
    else:
        rem_density.append(np.array(data['x_rem_density'], dtype=np.single)[0])
print(rem_density)

#REM percentage
rem_per = []
for i in range(len(abs_cortisol)):
    ids = abs_cortisol[i].split('_')
    data = df.loc[df['id'] == ids[0]]
    if ids[1] == 'o':
        rem_per.append(np.array(data['o_rem_per'], dtype=np.single)[0])
    else:
        rem_per.append(np.array(data['x_rem_per'], dtype=np.single)[0])
print(rem_per)
# Out:
# [7, 9, 8, 6, 8, 13, 7, 5, 10, 4, 10, 6, 6, 21, 6, 12, 8, 7, 6, 4, 8, 3, 8, 13, 7, 7, 7, 6, 4, 7, 7, 13, 16, 6, 18, 12, 7, 8, 6, 6, 8, 4, 7, 8, 6, 6, 9, 10, 5, 11, 6, 7, 10, 9, 4, 11, 8, 8, 2, 9, 1, 3, 8, 7, 3, 6, 5, 10, 7, 8, 3, 15, 7, 6, 5, 6, 9, 5]
# [7710, 6150, 4470, 5430, 5610, 7320, 3270, 4860, 4740, 2340, 3510, 2460, 5430, 3960, 2520, 5370, 6120, 4740, 1050, 4140, 5220, 1830, 6780, 2880, 4740, 6510, 5940, 4470, 5250, 3120, 3930, 3210, 3390, 3990, 4710, 4860, 3930, 5190, 3360, 3720, 2280, 2400, 2700, 4170, 2370, 4740, 4620, 6690, 5700, 3840, 5160, 4770, 5760, 4230, 5040, 3030, 4410, 3150, 2280, 4590, 1710, 4320, 4860, 3900, 1710, 3360, 1950, 5430, 4320, 3990, 1920, 5520, 2700, 2640, 2730, 3570, 3960, 3030]
# ...

# %%
# 傍晚cortisol排序 mean sd

l = 40
r = -1

index = 'rem_num'
# rem = np.array(df[index], dtype=np.int64)
rem = rem_num[l:r]
print()
print(index)
print(round(np.mean(rem), 2))
print(round(np.std(rem), 2))

index = 'rem_duration'
# rem = np.array(df[index], dtype=np.int64)
rem = rem_duration[l:r]
print()
print(index)
print(round(np.mean(rem), 2))
print(round(np.std(rem), 2))

index = 'rem_avg'
# rem = np.array(df[index], dtype=np.int64)
rem = rem_avg[l:r]
print()
print(index)
print(round(np.mean(rem), 2))
print(round(np.std(rem), 2))

index = 'rem_frag'
# rem = np.array(df[index], dtype=np.single)
rem = rem_frag[l:r]
print()
print(index)
print(round(np.mean(rem), 2))
print(round(np.std(rem), 2))

index = 'rem_latency'
# rem = np.array(df[index], dtype=np.int64)
rem = rem_latency[l:r]
print()
print(index)
print(round(np.mean(rem), 2))
print(round(np.std(rem), 2))

index = 'rem_density'
# rem = np.array(df[index], dtype=np.single)
rem = rem_density[l:r]
print()
print(index)
print(round(np.mean(rem), 2))
print(round(np.std(rem), 2))

index = 'rem_per'
# rem = np.array(df[index], dtype=np.single)
rem = rem_per[l:r]
print()
print(index)
print(round(np.mean(rem), 2))
print(round(np.std(rem), 2))
# Out:
# rem_num
# 6.95
# 2.8
#
# rem_duration
# 3797.84
# 1282.42
#
# rem_avg
# 629.03
# 316.14
#
# rem_frag
# 6.44
# 5.07
#
# rem_latency
# 7131.08
# 4278.41
#
# rem_density
# 21.73
# 10.56
#
# rem_per
# 14.84
# 5.03
